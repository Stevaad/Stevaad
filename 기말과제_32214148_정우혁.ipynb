# %% [markdown]
# <a href="https://colab.research.google.com/github/Stevaad/Stevaad/blob/main/%EA%B8%B0%EB%A7%90%EA%B3%BC%EC%A0%9C_32214148_%EC%A0%95%EC%9A%B0%ED%98%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 데이터 확인 및 선택

# %%
import pandas as pd
filename='/content/도로교통공단_부문별_뺑소니_교통사고_20181231.csv'
accident=pd.read_csv(filename,encoding='cp949')
accident.head()
# Out:
#    시도   시군구  발생건수  사망자수  부상자수  중상  경상  부상신고
# 0  서울   종로구    17     0    28   6  20     2
# 1  서울    중구    13     0    17   4  11     2
# 2  서울   용산구    41     1    57  15  42     0
# 3  서울   성동구    24     0    44   4  40     0
# 4  서울  동대문구    33     0    45  12  33     0

# %% [markdown]
# 데이터 기본정보 출력

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      226 non-null    object
#  1   시군구     226 non-null    object
#  2   발생건수    226 non-null    int64
#  3   사망자수    226 non-null    int64
#  4   부상자수    226 non-null    int64
#  5   중상      226 non-null    int64
#  6   경상      226 non-null    int64
#  7   부상신고    226 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 14.2+ KB

# %% [markdown]
# 기초통계량 출력하기

# %%
accident.describe()
# Out:
#              발생건수        사망자수        부상자수          중상          경상        부상신고
# count  226.000000  226.000000  226.000000  226.000000  226.000000  226.000000
# mean    33.632743    0.473451   49.110619    9.234513   38.491150    1.384956
# std     43.232833    0.795378   61.390562   10.403113   50.288787    3.163338
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.000000    0.000000    9.250000    2.000000    7.000000    0.000000
# 50%     18.500000    0.000000   29.500000    6.000000   21.500000    0.000000
# 75%     39.000000    1.000000   55.750000   13.000000   42.000000    1.000000
# max    261.000000    4.000000  351.000000   61.000000  301.000000   23.000000

# %%
accident.head()
# Out:
#    시도   시군구  발생건수  사망자수  부상자수  중상  경상  부상신고
# 0  서울   종로구    17     0    28   6  20     2
# 1  서울    중구    13     0    17   4  11     2
# 2  서울   용산구    41     1    57  15  42     0
# 3  서울   성동구    24     0    44   4  40     0
# 4  서울  동대문구    33     0    45  12  33     0

# %%
accident.sort_values('발생건수',ascending=False)
# Out:
#      시도  시군구  발생건수  사망자수  부상자수  중상   경상  부상신고
# 41   경기  수원시   261     1   351  42  301     8
# 55   경기  고양시   233     0   335  61  251    23
# 198  대구  달서구   224     2   297  49  237    11
# 46   경기  안산시   182     1   272  34  230     8
# 100  충남  천안시   174     3   270  31  239     0
# ..   ..  ...   ...   ...   ...  ..  ...   ...
# 123  전북  장수군     1     0     4   0    4     0
# 121  전북  진안군     1     1     0   0    0     0
# 98   충북  단양군     1     1     0   0    0     0
# 171  경북  울릉군     1     0     4   4    0     0
# 135  전남  곡성군     1     1     0   0    0     0
#
# [226 rows x 8 columns]

# %%
a=accident.sort_values('발생건수',ascending=False)
a.head(10)
# Out:
#      시도  시군구  발생건수  사망자수  부상자수  중상   경상  부상신고
# 41   경기  수원시   261     1   351  42  301     8
# 55   경기  고양시   233     0   335  61  251    23
# 198  대구  달서구   224     2   297  49  237    11
# 46   경기  안산시   182     1   272  34  230     8
# 100  충남  천안시   174     3   270  31  239     0
# 211  광주   서구   166     1   264  15  244     5
# 53   경기  시흥시   165     4   221  38  167    16
# 205  인천   서구   161     3   207  18  181     8
# 62   경기  용인시   158     1   231  58  167     6
# 42   경기  성남시   143     2   220  48  160    12

# %% [markdown]
# 데이터 빈도수 출력

# %%
count=accident['시도'].value_counts()
count
pd.DataFrame(count)
# Out:
#     시도
# 경기  31
# 서울  25
# 전남  22
# 경북  22
# 강원  17
# 경남  17
# 부산  16
# 충남  15
# 전북  14
# 충북  11
# 인천  10
# 대구   8
# 광주   5
# 대전   5
# 울산   5
# 제주   2
# 세종   1

# %% [markdown]
# 데이터선택

# %%
#가장 많은 사고가 적게 지역을 출력하시오
a=accident['발생건수']==accident['발생건수'].max()
accident[a]
# Out:
#     시도  시군구  발생건수  사망자수  부상자수  중상   경상  부상신고
# 41  경기  수원시   261     1   351  42  301     8

# %%
#가장 적은 사고가 일어난 지역
a=accident['발생건수']==accident['발생건수'].min()
accident[a]
# Out:
#      시도  시군구  발생건수  사망자수  부상자수  중상  경상  부상신고
# 98   충북  단양군     1     1     0   0   0     0
# 121  전북  진안군     1     1     0   0   0     0
# 123  전북  장수군     1     0     4   0   4     0
# 135  전남  곡성군     1     1     0   0   0     0
# 171  경북  울릉군     1     0     4   4   0     0

# %% [markdown]
# 데이터전처리

# %%
accident.isnull().sum()
# Out:
# 시도      0
# 시군구     0
# 발생건수    0
# 사망자수    0
# 부상자수    0
# 중상      0
# 경상      0
# 부상신고    0
# dtype: int64

# %% [markdown]
# 데이터 가공 및 그룹핑

# %%
accident.drop(['부상신고'],axis=1,inplace=True)

# %%
accident.columns
# Out:
# Index(['시도', '시군구', '발생건수', '사망자수', '부상자수', '중상', '경상'], dtype='object')

# %%
accident.columns=['시도','기초자치단체','발생수','사망','중상','경상','부상신고']
accident.head(5)
# Out:
#    시도 기초자치단체  발생수  사망  중상  경상  부상신고
# 0  서울    종로구   17   0  28   6    20
# 1  서울     중구   13   0  17   4    11
# 2  서울    용산구   41   1  57  15    42
# 3  서울    성동구   24   0  44   4    40
# 4  서울   동대문구   33   0  45  12    33

# %%
newdata=accident.groupby('시도').max()
newdata
# Out:
#    기초자치단체  발생수  사망   중상  경상  부상신고
# 시도
# 강원    횡성군   91   1  124  21    99
# 경기    화성시  261   4  351  61   301
# 경남    합천군   79   3  110  34    73
# 경북    포항시   58   3   88  14    71
# 광주     서구  166   1  264  15   244
# 대구     중구  224   2  297  49   237
# 대전     중구   69   2  123  16   107
# 부산   해운대구  101   0  129  23   105
# 서울    중랑구   75   1  130  28    97
# 세종     세종   19   0   27   4    23
# 울산     중구   56   3   99  27    71
# 인천     중구  161   3  207  29   181
# 전남    화순군   83   2  111  19    97
# 전북    진안군  119   2  156  24   130
# 제주    제주시   68   0  100  20    80
# 충남    홍성군  174   3  270  31   239
# 충북    충주시  114   1  190  46   144

# %%
newdata=accident.groupby('시도').min()
newdata
# Out:
#    기초자치단체  발생수  사망  중상  경상  부상신고
# 시도
# 강원    강릉시    2   0   2   0     1
# 경기    가평군    4   0   5   0     3
# 경남    거제시    3   0   3   1     1
# 경북    경산시    1   0   2   0     0
# 광주    광산구   13   0  20   1    19
# 대구     남구   23   0  38   7    25
# 대전    대덕구   11   0  15   4    11
# 부산    강서구    6   0  11   2     9
# 서울    강남구   13   0  17   2    11
# 세종     세종   19   0  27   4    23
# 울산     남구   21   0  24   7    17
# 인천    강화군    2   0   2   1     0
# 전남    강진군    1   0   0   0     0
# 전북    고창군    1   0   0   0     0
# 제주   서귀포시   14   0  20   4    15
# 충남    계룡시    3   0   3   0     2
# 충북    괴산군    1   0   0   0     0

# %% [markdown]
# 시각화 그래프

# %%
data=accident['시도'].value_counts()
data
# Out:
# 경기    31
# 서울    25
# 전남    22
# 경북    22
# 강원    17
# 경남    17
# 부산    16
# 충남    15
# 전북    14
# 충북    11
# 인천    10
# 대구     8
# 광주     5
# 대전     5
# 울산     5
# 제주     2
# 세종     1
# Name: 시도, dtype: int64

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
plt.title('시도별 교통사고수')
plt.plot(data,color='r',marker='o')
plt.xlabel('시도')
plt.ylabel('발생수')
plt.show()

# %%
data=accident['시도'].value_counts()
plt.figure(figsize=(12,10))
plt.bar(data.index,data)
plt.xlabel('시도')
plt.ylabel('발생수')
plt.show()
